# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "https://www.ffiec.gov/nicpubweb/nicweb/HCSGreaterThan10B.aspx"
page = urlopen(url)

soup = BeautifulSoup(page,"lxml")
soup
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-f21c773f8c72> in <module>()
# ----> 1 from urllib.request import urlopen
#       2 from bs4 import BeautifulSoup
#       3
#       4 url = "https://www.ffiec.gov/nicpubweb/nicweb/HCSGreaterThan10B.aspx"
#       5 page = urlopen(url)
#
# ImportError: No module named request

# %%
table  = soup.find('table',class_ = 'datagrid')
table
# Out:
# <table border="1" cellpadding="3" cellspacing="0" class="datagrid" id="dgTop50" rules="rows" title="Holding companies with assets greater than $10 billion summary" width="100%">
# <tr align="left" class="datagridH">
# <th scope="col"><font color="Blue" face="Arial" size="3"><b>Rank</b></font></th><th scope="col"><font color="Blue" face="Arial" size="3"><b>Institution Name (RSSD ID)</b></font></th><th scope="col"><font color="Blue" face="Arial" size="3"><b>Location</b></font></th><th align="right" scope="col"><font color="Blue" face="Arial" size="3"><b>06/30/2016 Total Assets</b></font></th>
# </tr><tr class="datagridI">
# <td><font face="Arial" size="3">1</font></td><td><font face="Arial" size="3">
# <a href="InstitutionProfile.aspx?parID_Rssd=1039502&amp;parDT_END=99991231" id="dgTop50_HyperLink1_0" target="_self">JPMORGAN CHASE &amp; CO. (1039502)</a>
# </font></td><td><font face="Arial" size="3">NEW YORK, NY</font></td><td align="right"><font face="Arial" size="3">$2,466,096,000</font></td>
# </tr><tr class="datagridAI">
# <td><font face="Arial" size="3">2</font></td><td><font face="Arial" size="3">
# <a href="InstitutionProfile.aspx?parID_Rssd=1073757&amp;parDT_END=99991231" id="dgTop50_HyperLink1_1" target="_self">BANK OF AMERICA CORPORATION (1073757)</a>
# </font></td><td><font face="Arial" size="3">CHARLOTTE, NC</font></td><td align="right"><font face="Arial" size="3">$2,189,811,000</font></td>
# </tr><tr class="datagridI">
# <td><font face="Arial" size="3">3</font></td><td><font face="Arial" size="3">
# <a href="InstitutionProfile.aspx?parID_Rssd=1120754&amp;parDT_END=99991231" id="dgTop50_HyperLink1_2" target="_self">WELLS FARGO &amp; COMPANY (1120754)</a>
# </font></td><td><font face="Arial" size="3">SAN FRANCISCO, CA</font></td><td align="right"><font face="Arial" size="3">$1,889,235,000</font></td>
# </tr><tr class="datagridAI">
# <td><font face="Arial" size="3">4</font></td><td><font face="Arial" size="3">
# <a href="InstitutionProfile.aspx?parID_Rssd=1951350&amp;parDT_END=99991231" id="dgTop50_HyperLink1_3" target="_self">CITIGROUP INC. (1951350)</a>
# </font></td><td><font face="Arial" size="3">NEW YORK, NY</font></td><td align="right"><font face="Arial" size="3">$1,818,771,000</font></td>
# </tr><tr class="datagridI">
# <td><font face="Arial" size="3">5</font></td><td><font face="Arial" size="3">
# <a href="InstitutionProfile.aspx?parID_Rssd=2380443&amp;parDT_END=99991231" id="dgTop50_HyperLink1_4" target="_self">GOLDMAN SACHS GROUP, INC., THE (2380443)</a>
# </font></td><td><font face="Arial" size="3">NEW YORK, NY</font></td><td align="right"><font face="Arial" size="3">$896,870,000</font></td>
# </tr><tr class="datagridAI">
# <td><font face="Arial" size="3">6</font></td><td><font face="Arial" size="3">
# <a href="InstitutionProfile.aspx?parID_Rssd=2162966&amp;parDT_END=99991231" id="dgTop50_HyperLink1_5" target="_self">MORGAN STANLEY (2162966)</a>
# </font></td><td><font face="Arial" size="3">NEW YORK, NY</font></td><td align="right"><font face="Arial" size="3">$828,873,000</font></td>
# </tr><tr class="datagridI">
# <td><font face="Arial" size="3">7</font></td><td><font face="Arial" size="3">
# <a href="InstitutionProfile.aspx?parID_Rssd=1119794&amp;parDT_END=99991231" id="dgTop50_HyperLink1_6" target="_self">U.S. BANCORP (1119794)</a>
# </font></td><td><font face="Arial" size="3">MINNEAPOLIS, MN</font></td><td align="right"><font face="Arial" size="3">$438,463,000</font></td>
# </tr><tr class="datagridAI">
# <td><font face="Arial" size="3">8</font></td><td><font face="Arial" size="3">
# <a href="InstitutionProfile.aspx?parID_Rssd=3587146&amp;parDT_END=99991231" id="dgTop50_HyperLink1_7" target="_self">BANK OF NEW YORK MELLON CORPORATION, THE (3587146)</a>
# </font></td><td><font face="Arial" size="3">NEW YORK, NY</font></td><td align="right"><font face="Arial" size="3">$372,351,000</font></td>
# </tr><tr class="datagridI">
# <td><font face="Arial" size="3">9</font></td><td><font face="Arial" size="3">
# <a href="InstitutionProfile.aspx?parID_Rssd=1069778&amp;parDT_END=99991231" id="dgTop50_HyperLink1_8" target="_self">PNC FINANCIAL SERVICES GROUP, INC., THE (1069778)</a>
# </font></td><td><font face="Arial" size="3">PITTSBURGH, PA</font></td><td align="right"><font face="Arial" size="3">$361,528,406</font></td>
# </tr><tr class="datagridAI">
# <td><font face="Arial" size="3">10</font></td><td><font face="Arial" size="3">
# <a href="InstitutionProfile.aspx?parID_Rssd=2277860&amp;parDT_END=99991231" id="dgTop50_HyperLink1_9" target="_self">CAPITAL ONE FINANCIAL CORPORATION (2277860)</a>
# </font></td><td><font face="Arial" size="3">MCLEAN, VA</font></td><td align="right"><font face="Arial" size="3">$339,247,718</font></td>
# </tr><tr class="datagridI">
# <td><font face="Arial" size="3">11</font></td><td><font face="Arial" size="3">
# <a href="InstitutionProfile.aspx?parID_Rssd=3232316&amp;parDT_END=99991231" id="dgTop50_HyperLink1_10" target="_self">HSBC NORTH AMERICA HOLDINGS INC. (3232316)</a>
# </font></td><td><font face="Arial" size="3">NEW YORK, NY</font></td><td align="right"><font face="Arial" size="3">
font></td><td><font face="Arial" size="3">
# <a href="InstitutionProfile.aspx?parID_Rssd=3153130&amp;parDT_END=99991231" id="dgTop50_HyperLink1_111" target="_self">BANC OF CALIFORNIA, INC. (3153130)</a>
# </font></td><td><font face="Arial" size="3">IRVINE, CA</font></td><td align="right"><font face="Arial" size="3">$10,157,662</font></td>
# </tr><tr class="datagridI">
# <td><font face="Arial" size="3">113</font></td><td><font face="Arial" size="3">
# <a href="InstitutionProfile.aspx?parID_Rssd=1427239&amp;parDT_END=99991231" id="dgTop50_HyperLink1_112" target="_self">EASTERN BANK CORPORATION (1427239)</a>
# </font></td><td><font face="Arial" size="3">BOSTON, MA</font></td><td align="right"><font face="Arial" size="3">$10,025,463</font></td>
# </tr>
# </table>

# %%
table  = soup.find('table',class_ = 'datagrid')
header = []
for row in table.findAll("tr",class_='datagridH'):
    head= row.findAll('th')
    for i in range(4):
        header.append(head[i].find(text=True))
header
# Out:
# ['Rank', 'Institution Name (RSSD ID)', 'Location', '06/30/2016 Total Assets']

# %%
table  = soup.find('table',class_ = 'datagrid')
header = []
for row in table.findAll("tr",class_='datagridH'):
    head= row.findAll('th')
    for i in range(4):
        header.append(head[i].find(text=True))
date_of_data = header[-1].split(' ')[0]
RANK = []
InstutionName = []
Location = []
TotalAssets = []
date22 = []
for row in table.findAll("tr"):
    cells= row.findAll("td")
    if len(cells) == 4:
        RANK.append(cells[0].find(text=True))
        InstutionName.append(cells[1].find('a').contents[0])
        Location.append(cells[2].find(text=True))
        TotalAssets.append(cells[3].find(text=True))
        date22.append(date_of_data)

import pandas as pd
df = pd.DataFrame(RANK,columns = ['RANK'])
df['InstutionName'] = InstutionName
df['Location'] = Location
df['TotalAssets'] = TotalAssets
df['Date'] = date22
print(df.head())
# Out:
#   RANK                             InstutionName           Location  \
# 0    1            JPMORGAN CHASE & CO. (1039502)       NEW YORK, NY
# 1    2     BANK OF AMERICA CORPORATION (1073757)      CHARLOTTE, NC
# 2    3           WELLS FARGO & COMPANY (1120754)  SAN FRANCISCO, CA
# 3    4                  CITIGROUP INC. (1951350)       NEW YORK, NY
# 4    5  GOLDMAN SACHS GROUP, INC., THE (2380443)       NEW YORK, NY
#
#       TotalAssets        Date
# 0  $2,466,096,000  06/30/2016
# 1  $2,189,811,000  06/30/2016
# 2  $1,889,235,000  06/30/2016
# 3  $1,818,771,000  06/30/2016
# 4    $896,870,000  06/30/2016

# %%
len(soup.find('table',class_ = 'datagrid').findAll("td"))
# Out:
# 452

# %%
import pandas as pd
table  = soup.find('table',class_ = 'datagrid')
header = []
RANK = []
InstutionName = []
Location = []
TotalAssets = []
date22 = []
for row in table.findAll("tr"):
    if len(header) <= 0:
        for row2 in table.findAll("tr",class_='datagridH'):
            head= row2.findAll('th')
            for i in range(4):
                header.append(head[i].find(text=True))
        
    cells = row.findAll("td") 
    #print(header)
    if len(cells) == 4:        
        RANK.append(cells[0].find(text=True))
        InstutionName.append(cells[1].find('a').contents[0])
        Location.append(cells[2].find(text=True))
        TotalAssets.append(int(cells[3].find(text=True).replace("$","").replace(",","")))        
        date22.append(header[-1].split(' ')[0])
df = pd.DataFrame({header[0]:RANK,header[1]:InstutionName,header[2]:Location,'Total Assets':TotalAssets,'Date':pd.to_datetime(date22)})

# %%
df.dtypes
# Out:
# Date                          datetime64[ns]
# Institution Name (RSSD ID)            object
# Location                              object
# Rank                                  object
# Total Assets                           int64
# dtype: object

# %%
import os
import time
from selenium.webdriver.support.ui import *
from selenium import webdriver

chromedriver = "C:\\Users\\lalit\\Downloads\\chromedriver.exe"
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)

driver.get("https://www.ffiec.gov/nicpubweb/nicweb/HCSGreaterThan10B.aspx")
select = Select(driver.find_element_by_id("DateDropDown"))
options = select.options
count = 0
for o in options:
    count += count + 1
    print(o.text)
    print(count)
    o.click()
    #time.sleep(10)
    print("Not matched")
    if(o.text == '20150930'):
        print("Matched")
        table  = soup.find('table',class_ = 'datagrid')
        header = []
        RANK = []
        InstutionName = []
        Location = []
        TotalAssets = []
        date22 = []
        for row in table.findAll("tr"):
            if len(header) <= 0:
                for row2 in table.findAll("tr",class_='datagridH'):
                    head= row2.findAll('th')
                    for i in range(4):
                        header.append(head[i].find(text=True))

            cells = row.findAll("td") 
            #print(header)
            if len(cells) == 4:        
                RANK.append(cells[0].find(text=True))
                InstutionName.append(cells[1].find('a').contents[0])
                Location.append(cells[2].find(text=True))
                TotalAssets.append(int(cells[3].find(text=True).replace("$","").replace(",","")))        
                date22.append(header[-1].split(' ')[0])
        df = pd.DataFrame({header[0]:RANK,header[1]:InstutionName,header[2]:Location,'Total Assets':TotalAssets,'Date':pd.to_datetime(date22)})
        print(df)
# Out:
# 20160630
# 1
# Not matched
# 20160331
# 3
# Not matched
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-6-6acf17cf3f40> in <module>()
#      19     #time.sleep(10)
#      20     print("Not matched")
# ---> 21     if(o.text == '20150930'):
#      22         print("Matched")
#      23         table  = soup.find('table',class_ = 'datagrid')
#
# C:\Users\lalit\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      66     def text(self):
#      67         """The text of the element."""
# ---> 68         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      69
#      70     def click(self):
#
# C:\Users\lalit\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     459             params = {}
#     460         params['id'] = self._id
# --> 461         return self._parent.execute(command, params)
#     462
#     463     def find_element(self, by=By.ID, value=None):
#
# C:\Users\lalit\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     234         response = self.command_executor.execute(driver_command, params)
#     235         if response:
# --> 236             self.error_handler.check_response(response)
#     237             response['value'] = self._unwrap_value(
#     238                 response.get('value', None))
#
# C:\Users\lalit\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     190         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     191             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 192         raise exception_class(message, screen, stacktrace)
#     193
#     194     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=53.0.2785.116)
#   (Driver info: chromedriver=2.24.417431 (9aea000394714d2fbb20850021f6204f2256b9cf),platform=Windows NT 10.0.14393 x86_64)

# %%
#####Original Case
import os
import pandas as pd
from bs4 import BeautifulSoup
import time
from selenium.webdriver.support.ui import *
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait


del RANK,header,InstutionName,Location,TotalAssets,date22
url = "https://www.ffiec.gov/nicpubweb/nicweb/HCSGreaterThan10B.aspx"
page = urlopen(url)

soup = BeautifulSoup(page,"lxml")

chromedriver = "C:\\Users\\lalit\\Downloads\\chromedriver.exe"
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)

driver.get("https://www.ffiec.gov/nicpubweb/nicweb/HCSGreaterThan10B.aspx")
select = Select(driver.find_element_by_id("DateDropDown"))
options = select.options
values = []

for o in options:
    values.append(o.text)
for v in values: 
    driver.find_element_by_xpath("//select[@name='DateDropDown']/option[text()= " + v + "]").click()
    soup = BeautifulSoup(driver.page_source, "lxml")
    time.sleep(10)  

    table  = soup.find('table',class_ = 'datagrid')

    if 'header' not in dir() and 'RANK' not in dir() and 'InstitutionName' not in dir() and 'Location' not in dir() and 'TotalAssets' not in dir() and 'date22' not in dir():
        print("Getting first time")
        header = []
        RANK = []
        InstutionName = []
        Location = []
        TotalAssets = []
        date22 = []
        for row in table.findAll("tr"):
            if len(header) <= 0:
                for row2 in table.findAll("tr",class_='datagridH'):
                    head= row2.findAll('th')
                    for i in range(4):
                        header.append(head[i].find(text=True))

            cells = row.findAll("td")             
            if len(cells) == 4:        
                RANK.append(cells[0].find(text=True))
                InstutionName.append(cells[1].find('a').contents[0])
                Location.append(cells[2].find(text=True))
                TotalAssets.append(int(cells[3].find(text=True).replace("$","").replace(",","")))        
                date22.append(header[-1].split(' ')[0])
    else:
        for row in table.findAll("tr"):
            cells = row.findAll("td") 
            if len(cells) == 4:        
                RANK.append(cells[0].find(text=True))
                InstutionName.append(cells[1].find('a').contents[0])
                Location.append(cells[2].find(text=True))
                TotalAssets.append(int(cells[3].find(text=True).replace("$","").replace(",","")))                
                date22.append(v)
df = pd.DataFrame({header[0]:RANK,header[1]:InstutionName,header[2]:Location,'Total Assets':TotalAssets,'Date':pd.to_datetime(date22)})
df.to_csv("E:\\Output_Stack.csv")
print("Completed")
# Out:
# Getting first time
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-134-87d63ee168b5> in <module>()
#      27     values.append(o.text)
#      28 for v in values:
# ---> 29     driver.find_element_by_xpath("//select[@name='DateDropDown']/option[text()= " + v + "]").click()
#      30     soup = BeautifulSoup(driver.page_source, "lxml")
#      31     time.sleep(10)
#
# C:\Users\lalit\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     291             driver.find_element_by_xpath('//div/td[1]')
#     292         """
# --> 293         return self.find_element(by=By.XPATH, value=xpath)
#     294
#     295     def find_elements_by_xpath(self, xpath):
#
# C:\Users\lalit\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     750         return self.execute(Command.FIND_ELEMENT, {
#     751             'using': by,
# --> 752             'value': value})['value']
#     753
#     754     def find_elements(self, by=By.ID, value=None):
#
# C:\Users\lalit\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     234         response = self.command_executor.execute(driver_command, params)
#     235         if response:
# --> 236             self.error_handler.check_response(response)
#     237             response['value'] = self._unwrap_value(
#     238                 response.get('value', None))
#
# C:\Users\lalit\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     190         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     191             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 192         raise exception_class(message, screen, stacktrace)
#     193
#     194     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=53.0.2785.116)
#   (Driver info: chromedriver=2.24.417431 (9aea000394714d2fbb20850021f6204f2256b9cf),platform=Windows NT 10.0.14393 x86_64)

# %%
from __future__ import print_function

import sys
import time

from progressbar import AnimatedMarker, Bar, BouncingBar, Counter, ETA, \
    FileTransferSpeed, FormatLabel, Percentage, \
    ProgressBar, ReverseBar, RotatingMarker, \
    SimpleProgress, Timer, AdaptiveETA

examples = [1,2,3]



def example16():
    widgets = [FormatLabel('Bouncer: value %(value)d - '), BouncingBar()]
    pbar = ProgressBar(widgets=widgets)
    for i in pbar((i for i in range(100))):
        time.sleep(0.001)


example16()
# Out:
# Bouncer: value 99 - |#########################################################|

# %%
unstackver = df.unstack(level=0)
unstackver.to_csv("E:\\Output_Unstack.csv")
